# %% [markdown]
# <a href="https://colab.research.google.com/github/dSudario9/Amostragem/blob/main/Amostragem__Estatistica_Inferencial_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #
# **Assignment - Amostragem**

# %% [markdown]
# O PISA (Programme for International Student Assessment) é um índice de educação gerado a cada três anos pela OCDE (Organização de Cooperação e Desenvolvimento Econômico). O PISA mede a habilidade de adolescentes de 15 anos em usar conhecimentos de leitura, matemática e ciência para lidar com problemas da vida real.
# Este vídeo no Youtube [PISA - Medindo o sucesso dos estudantes em todo o mundo](https://https://www.youtube.com/watch?v=wAoBdGTEKJ8)
# explica sobre como funciona a aplicação do teste.
# Assista ao vídeo e responda as questões:

# %% [markdown]
# ### Utilize a base de dados Iris (“toy dataset” – base de dados para fins educativos) para replicar alguns tipos de amostragem.

# %%
import pandas as pd
import numpy as np
import random 
from numpy import random
from random import sample
from sklearn import datasets

# %%
iris_df = pd.DataFrame(datasets.load_iris().data)

# %%
iris_df.columns = datasets.load_iris().feature_names

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ### Parte prática no Colab!

# %% [markdown]
# ### 1. Faça uma Amostragem aleatória simples: 20 itens
# ### 2. Faça uma Amostragem de Julgamento: itens com “petal width” maior que 2.0
# ### 3. Faça uma Amostragem de Conveniência: primeiros 30 itens

# %% [markdown]
# **Amostragem aleatória simples: 20 itens**

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# count         150.000000        150.000000         150.000000        150.000000
# mean            5.843333          3.057333           3.758000          1.199333
# std             0.828066          0.435866           1.765298          0.762238
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.350000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %%
random_sample_iris_df = (random.sample(range(150), k=20))
print(random_sample_iris_df)
# Out:
# [105, 111, 9, 109, 26, 83, 144, 67, 112, 20, 122, 39, 134, 95, 148, 117, 149, 45, 13, 89]

# %% [markdown]
# **Amostragem de Julgamento: itens com “petal width” maior que 2.0**

# %%
amostraj=iris_df.loc[iris_df['petal width (cm)']>2.0]
amostraj
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 100                6.3               3.3                6.0               2.5
# 102                7.1               3.0                5.9               2.1
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 109                7.2               3.6                6.1               2.5
# 112                6.8               3.0                5.5               2.1
# 114                5.8               2.8                5.1               2.4
# 115                6.4               3.2                5.3               2.3
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 120                6.9               3.2                5.7               2.3
# 124                6.7               3.3                5.7               2.1
# 128                6.4               2.8                5.6               2.1
# 132                6.4               2.8                5.6               2.2
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 148                6.2               3.4                5.4               2.3

# %% [markdown]
# **Amostragem de Conveniência: primeiros 30 itens**

# %%
iris_df.head(31)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# 11                4.8               3.4                1.6               0.2
# 12                4.8               3.0                1.4               0.1
# 13                4.3               3.0                1.1               0.1
# 14                5.8               4.0                1.2               0.2
# 15                5.7               4.4                1.5               0.4
# 16                5.4               3.9                1.3               0.4
# 17                5.1               3.5                1.4               0.3
# 18                5.7               3.8                1.7               0.3
# 19                5.1               3.8                1.5               0.3
# 20                5.4               3.4                1.7               0.2
# 21                5.1               3.7                1.5               0.4
# 22                4.6               3.6                1.0               0.2
# 23                5.1               3.3                1.7               0.5
# 24                4.8               3.4                1.9               0.2
# 25                5.0               3.0                1.6               0.2
# 26                5.0               3.4                1.6               0.4
# 27                5.2               3.5                1.5               0.2
# 28                5.2               3.4                1.4               0.2
# 29                4.7               3.2                1.6               0.2
# 30                4.8               3.1                1.6               0.2
